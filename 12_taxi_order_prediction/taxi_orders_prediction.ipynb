# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Первичный-обзор-данных" data-toc-modified-id="Первичный-обзор-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Первичный обзор данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Анализ-трендов-и-сезонности" data-toc-modified-id="Анализ-трендов-и-сезонности-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ трендов и сезонности</a></span></li><li><span><a href="#Новые-признаки" data-toc-modified-id="Новые-признаки-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Новые признаки</a></span></li><li><span><a href="#Делим-данные-на-выборки" data-toc-modified-id="Делим-данные-на-выборки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Делим данные на выборки</a></span></li><li><span><a href="#Масштабируем-данные" data-toc-modified-id="Масштабируем-данные-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Масштабируем данные</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Константная-модель" data-toc-modified-id="Константная-модель-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Константная модель</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#SGDRegressor" data-toc-modified-id="SGDRegressor-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>SGDRegressor</a></span></li><li><span><a href="#XGBRegressor" data-toc-modified-id="XGBRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>XGBRegressor</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#LGBMRegressor" data-toc-modified-id="LGBMRegressor-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>LGBMRegressor</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#SGDRegressor" data-toc-modified-id="SGDRegressor-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>SGDRegressor</a></span></li><li><span><a href="#XGBRegressor" data-toc-modified-id="XGBRegressor-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>XGBRegressor</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#LGBMRegresor" data-toc-modified-id="LGBMRegresor-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>LGBMRegresor</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Для исследования собраны исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Для предсказания построим и обучим модель.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Данные представляют собой таблицу из 2 столбцов:
#
# - `datetime` - время (дата и час)
# - `num_orders` - кол-во заказов в этот временной промежуток
#
# Перед нами стоят следующие задачи:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами.
# 4. Проверить данные на тестовой выборке и сделать выводы.

# %% [markdown]
# ## Подготовка

# %%
# импортируем необходимые инструменты

# библиотека pandas для работы с таблицами
import pandas as pd
# библиотека numpy для математических вычислений
import numpy as np
# для визуализации
import matplotlib.pyplot as plt
import seaborn as sns
# для анализа тренда и сезонности 
from statsmodels.tsa.seasonal import seasonal_decompose
# первым делим данные на выборки, вторым ищем оптимальные параметры для модели
from sklearn.model_selection import train_test_split, GridSearchCV
# для оценки качества модели
from sklearn.metrics import mean_squared_error, make_scorer
# для масштабирования данных
from sklearn.preprocessing import StandardScaler
# модели, которые будем рассматривать:
# линейная регрессия
from sklearn.linear_model import LinearRegression
# модель стохастического градиентного спуска
from sklearn.linear_model import SGDRegressor
# модели градиентного бустинга:
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Первичный обзор данных

# %%
# сохраняем таблицу с данными в переменную
# Столбец datetime приведем к формату даты и переведем в индекс через index_col, parse_dates:
taxi_data = pd.read_csv('/datasets/taxi.csv', parse_dates=[0], index_col=0)

# %%
# выведем первые 10 строк
taxi_data.head(10)
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32
# 2018-03-01 00:50:00          21
# 2018-03-01 01:00:00           7
# 2018-03-01 01:10:00           5
# 2018-03-01 01:20:00          17
# 2018-03-01 01:30:00          12

# %%
# отсортируем данные по дате
taxi_data.sort_index(inplace=True)

# %%
# у нас в таблице представлены данные с интервалом в 10 мин, но для анализа нам нужно изменить этот интерва на 1 час
taxi_data = taxi_data.resample('1H').sum()

# %%
taxi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4416 non-null   int64
# dtypes: int64(1)
# memory usage: 69.0 KB

# %%
taxi_data.describe()
# Out:
#         num_orders
# count  4416.000000
# mean     84.422781
# std      45.023853
# min       0.000000
# 25%      54.000000
# 50%      78.000000
# 75%     107.000000
# max     462.000000

# %%
# проверим, есть ли аномальные значения - построим график с усами
plot = sns.catplot(data=taxi_data, kind='box', height=6, aspect=2, legend_out=False)
plot.set_axis_labels(x_var='Orders per hour')
plot.set
plot.fig.suptitle('Taxi orders per hour', y=1.1);

# %% [markdown]
# В большинстве случае, происходит около 70-120 заказов такси в час, но говорить о том, что остальное - выбросы, мы с уверенностью не можем.

# %% [markdown]
# ### Выводы

# %% [markdown]
# - В данных нет пропусков и выбросов;
# - данные рассемплированы;
# - общее число объектов - 4 416.

# %% [markdown]
# ## Анализ

# %% [markdown]
# ### Анализ трендов и сезонности

# %%
# посмотрим является ли временной ряд стационарным
taxi_data.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# Временной ряд сложно назвать стационарным, т.к. его среднее значение плавно растет. Делать прогнозы по нестационарным временным рядам сложнее: свойства меняются слишком быстро.

# %%
# Посмотрим на тренд и сезонность данных с помощью функции seasonal_decompose(). 
# Она раскладывает временной ряд на три составляющие: тренд, сезонность и остаток
decomposed = seasonal_decompose(taxi_data)

# %%
# построим графики с каждым из атрибутов 
plt.figure(figsize=(12, 8))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# Тренд по кол-ву заказов растущий, но, скорее всего, это связано с ростом и развитием самой компании, нежели с сезонностью.
#
# Уже давно не секрет, что у услуг такси нет сезонности по месяцам, только небольшой спад в летние месяцы, т.к. часть постоянных и редких клиентов находятся в отпуске. Сезонность можно увидеть в кол-ве заказов в рамках одного дня: наименьшее кол-во заказов с 4 до 7 утра, наибольшее кол-во с 23 до 01 ночи.
#
# К слову, Яндекс пришел к таким выводам еще в 2013 г. [Ссылка на статью про заказы такси в Москве](https://yandex.ru/company/researches/2013/ya_moscow_taxi_2013#toc2.1).

# %% [markdown]
# Вот и мы не видим на графиках сезонности на периоде в несколько месяцев, поэтому нужно рассмотреть более короткий временной отрезок. Рассмотрим тренд и сезонность в рамках двух первых месяцев выборки - за март и апрель.

# %%
# возьмем данные не за месяцы

decomposed_short = seasonal_decompose(taxi_data["2018-03-05":"2018-04-29"]["num_orders"])
fig2,ax2 = plt.subplots(8,2,figsize = (25,60))
# Trend
    # Март
ax2[0][0].plot(decomposed_short.trend["2018-03-05":"2018-03-11"].index.dayofweek,
            decomposed_short.trend["2018-03-05":"2018-03-11"].values,linewidth=4)
ax2[0][0].set_title("Trend перавая неделя марта")

ax2[1][0].plot(decomposed_short.trend["2018-03-12":"2018-03-18"].index.dayofweek,
            decomposed_short.trend["2018-03-12":"2018-03-18"].values,linewidth=4)
ax2[1][0].set_title("Trend вторая неделя марта")

ax2[2][0].plot(decomposed_short.trend["2018-03-19":"2018-03-25"].index.dayofweek,
            decomposed_short.trend["2018-03-19":"2018-03-25"].values,linewidth=4)
ax2[2][0].set_title("Trend третья неделя марта")

ax2[3][0].plot(decomposed_short.trend["2018-03-26":"2018-04-01"].index.dayofweek,
            decomposed_short.trend["2018-03-26":"2018-04-01"].values,linewidth=4)
ax2[3][0].set_title("Trend четвертая неделя марта")

    # Апрель
ax2[0][1].plot(decomposed_short.trend["2018-04-02":"2018-04-08"].index.dayofweek,
            decomposed_short.trend["2018-04-02":"2018-04-08"].values,linewidth=4)
ax2[0][1].set_title("Trend перавая неделя апреля")

ax2[1][1].plot(decomposed_short.trend["2018-04-09":"2018-04-15"].index.dayofweek,
            decomposed_short.trend["2018-04-09":"2018-04-15"].values,linewidth=4)
ax2[1][1].set_title("Trend вторая неделя апреля")

ax2[2][1].plot(decomposed_short.trend["2018-04-16":"2018-04-22"].index.dayofweek,
            decomposed_short.trend["2018-04-16":"2018-04-22"].values,linewidth= 4)
ax2[2][1].set_title("Trend третья неделя апреля")

ax2[3][1].plot(decomposed_short.trend["2018-04-23":"2018-04-29"].index.dayofweek,
            decomposed_short.trend["2018-04-23":"2018-04-29"].values,linewidth= 4)
ax2[3][1].set_title("Trend четвертая неделя апреля")
# Seasonality
    # Март
ax2[4][0].plot(decomposed_short.seasonal["2018-03-05":"2018-03-11"].index.dayofweek,
            decomposed_short.seasonal["2018-03-05":"2018-03-11"].values,linewidth=4)
ax2[4][0].set_title("Seasonality перавая неделя марта")

ax2[5][0].plot(decomposed_short.seasonal["2018-03-12":"2018-03-18"].index.dayofweek,
            decomposed_short.seasonal["2018-03-12":"2018-03-18"].values,linewidth=4)
ax2[5][0].set_title("Seasonality вторая неделя марта")

ax2[6][0].plot(decomposed_short.seasonal["2018-03-19":"2018-03-25"].index.dayofweek,
            decomposed_short.seasonal["2018-03-19":"2018-03-25"].values,linewidth=4)
ax2[6][0].set_title("Seasonality третья неделя марта")

ax2[7][0].plot(decomposed_short.seasonal["2018-03-26":"2018-04-01"].index.dayofweek,
            decomposed_short.seasonal["2018-03-26":"2018-04-01"].values,linewidth=4)
ax2[7][0].set_title("Seasonality четвертая неделя марта")

    # Апрель
ax2[4][1].plot(decomposed_short.seasonal["2018-04-02":"2018-04-08"].index.dayofweek,
            decomposed_short.seasonal["2018-04-02":"2018-04-08"].values,linewidth=4)
ax2[4][1].set_title("Seasonality перавая неделя апреля")

ax2[5][1].plot(decomposed_short.seasonal["2018-04-09":"2018-04-15"].index.dayofweek,
            decomposed_short.seasonal["2018-04-09":"2018-04-15"].values,linewidth=4)
ax2[5][1].set_title("Seasonality вторая неделя апреля")

ax2[6][1].plot(decomposed_short.seasonal["2018-04-16":"2018-04-22"].index.dayofweek,
            decomposed_short.seasonal["2018-04-16":"2018-04-22"].values,linewidth= 4)
ax2[6][1].set_title("Seasonality третья неделя апреля")

ax2[7][1].plot(decomposed_short.seasonal["2018-04-23":"2018-04-29"].index.dayofweek,
            decomposed_short.seasonal["2018-04-23":"2018-04-29"].values,linewidth= 4)
ax2[7][1].set_title("Seasonality четвертая неделя апреля")
# Out:
# Text(0.5, 1.0, 'Seasonality четвертая неделя апреля')

# %% [markdown]
# Как мы видим, на протяжений всего исследуемого периода сезонность остается неизменной: в начале каждого дня наблюдается пик, потом резкое падение, затем в течение дня количество заказов растет и к концу дня достигает нового пика. Можно заметить тренд на рост числа заказов в понедельник, тренд на падение заказов во вторник, который со 2 недели апреля меняется на рост. А так же тренд на рост заказов во второй половине недели.

# %% [markdown]
# ### Новые признаки

# %% [markdown]
# Чтобы ряд сделать стационарным, найдём разности его значений.

# %%
# объявим функцию, которая добавит в наш датафрейм новые данные - разности временного ряда, скользящее среднее и скользящее стандартное отклонение 
def make_features(data, max_lag, rolling_mean_size):
    data['difference'] = abs(data['num_orders'] - data['num_orders'].shift())
    #data['month'] = data.index.month
    #data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for i in range(1, max_lag + 1):
        data['lag_' + str(i)] = data['num_orders'].shift(i)
    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    data['std'] = data['num_orders'].shift().rolling(rolling_mean_size).std()

# %%
# добавим новые признаки в датафрейм
# make_features(taxi_data, 15, 15)
make_features(taxi_data, 2, 24)

# %%
# выведем таблицу с новыми признаками
taxi_data
# Out:
#                      num_orders  difference  dayofweek  hour  lag_1  lag_2  \
# datetime
# 2018-03-01 00:00:00         124         NaN          3     0    NaN    NaN
# 2018-03-01 01:00:00          85        39.0          3     1  124.0    NaN
# 2018-03-01 02:00:00          71        14.0          3     2   85.0  124.0
# 2018-03-01 03:00:00          66         5.0          3     3   71.0   85.0
# 2018-03-01 04:00:00          43        23.0          3     4   66.0   71.0
# ...                         ...         ...        ...   ...    ...    ...
# 2018-08-31 19:00:00         136        71.0          4    19  207.0  217.0
# 2018-08-31 20:00:00         154        18.0          4    20  136.0  207.0
# 2018-08-31 21:00:00         159         5.0          4    21  154.0  136.0
# 2018-08-31 22:00:00         223        64.0          4    22  159.0  154.0
# 2018-08-31 23:00:00         205        18.0          4    23  223.0  159.0
#
#                      rolling_mean        std
# datetime
# ...

# %% [markdown]
# Получить признаки для первых значений выборки нельзя: исторических данных по ним нет.

# %%
# удалим пропуски, получившиеся в процессе
taxi_data = taxi_data.dropna()

# %% [markdown]
# ### Делим данные на выборки

# %%
# Функция train_test_split() из модуля sklearn.model_selection по умолчанию перемешивает данные. 
# Поэтому укажем аргумент shuffle равным False, т.к. данные обучающей выборки должны предшествовать 
# данным тестовой. Иначе тестирование модели будет некорректным: модель не должна обучаться на данных из будущего.
# По условиям задания тестовая выборка должна составлять 10% от всех данных.
train, test = train_test_split(taxi_data, shuffle = False, random_state = 12345, test_size = 0.1)

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b> Комментарий студента:</b>
# Пробывала добавлять валидационную выборку, но результат для тестовой был в таком случае гораздо хуже. Видимо при таком росте графика, чтобы добиться желаемого результата (rmse<=48) на тестовой выборке в 10% важно не разделять данные на валидационную выборку. И чем больше будет тестовая выборка, тем хуже она будет предсказываться </div>

# %%
# посмотрим на размеры получившихся выборок
train.shape, test.shape
# Out:
# ((3952, 8), (440, 8))

# %%
# разделим выборки на features и target. Целевой признак у нас - кол-во заказов
(train_features,
test_features) = (train.drop('num_orders',axis = 1),
                  test.drop('num_orders',axis = 1))
(train_target,
test_target) = (train['num_orders'],
                test['num_orders'])

# %% [markdown]
# ### Масштабируем данные

# %%
scaler = StandardScaler()
scaler.fit(train_features)

train_features = scaler.transform(train_features)
test_features = scaler.transform(test_features)

# %% [markdown]
# ###  Выводы

# %% [markdown]
# - данные проанализированы: рассмотрена сезонность и тренды как на всей выборке в целом, так и на более коротком промежутке;
# - проанализирован характер временного ряда;
# - временной ряд приведен к более стационарному виду за счет добавления разностей временного ряда в качестве новых признаков;
# - данные подготовлены для обучения моделей - разделены на выборки и отмасштабированы.

# %% [markdown]
# ## Обучение

# %% [markdown]
# Рассмотрим следующие моедли:
#
# - линейную регресиию **LinearRegression**;
# - модель стохастического градиентного спуска **SGDRegressor**;
# - модель градиентного бустинга **XGBRegressor**;
# - модель градиентного бустинга **CatBoostRegressor**;
# - модель градиентного бустинга **LGBMRegressor**.
#
# Но для начала зададим скорер, а также создадим и обучим константную модель, при с равнении с которой будем оценивать адекватность работы модели.

# %%
# для оценки качества разных моделей будем использовать метрику RMSE. Создадим scorer, 
# который в дальнейшем будем использовать для скоринга моделей, за основу как раз возьмем метрику RMSE.

def RMSE(target, predict):
    RMSE = mean_squared_error(target, predict) ** 0.5
    return RMSE

scorer = make_scorer(RMSE, greater_is_better=False)

# %%
def draw_plots(train_predicts):
    f, ax = plt.subplots(ncols=2, figsize=(20, 5))
    sns.lineplot(data=train_target.iloc[0: 72].values, ax=ax[0], label='True target')
    sns.lineplot(data=train_predicts[0: 72], ax=ax[0], label='Predictions')
    ax[0].grid()
    ax[0].set_title('Train start')
    ax[0].legend()
    sns.lineplot(data=train_target.iloc[-72: ].values, ax=ax[1], label='True target')
    sns.lineplot(data=train_predicts[-72: ], ax=ax[1], label='Predictions')
    ax[1].grid()
    ax[1].set_title('Train end')
    ax[1].legend()
    f.show()

# %% [markdown]
# ### Константная модель

# %%
# в качестве предсказаний выдерем значения одного из признаков с разностью временного ряда
dummy_train_predicts = train['lag_1']
dummy_mdl_rmse = RMSE(train_target, dummy_train_predicts)
f"RMSE для константной модели: {round(dummy_mdl_rmse, 2)}"
# Out:
# 'RMSE для константной модели: 36.19'

# %%
dummy_preds_and_true_target_comparison = pd.DataFrame({
    'dummy_predictions' : dummy_train_predicts,
    'true_target' : train_target
})

# %%
train_target
# Out:
# datetime
# 2018-03-02 00:00:00     90
# 2018-03-02 01:00:00    120
# 2018-03-02 02:00:00     75
# 2018-03-02 03:00:00     64
# 2018-03-02 04:00:00     20
#                       ...
# 2018-08-13 11:00:00    144
# 2018-08-13 12:00:00     92
# 2018-08-13 13:00:00    119
# 2018-08-13 14:00:00    102
# 2018-08-13 15:00:00    175
# Freq: H, Name: num_orders, Length: 3952, dtype: int64

# %%
dummy_preds_and_true_target_comparison['2018-08'].plot(figsize=(16,4), title='True and prediction values comparison');

# %% [markdown]
# ### LinearRegression

# %%
LR_mdl = LinearRegression()

# %%
# %%time
LR_mdl.fit(train_features, train_target)
# Out:
# CPU times: user 4.03 ms, sys: 0 ns, total: 4.03 ms
# Wall time: 2.64 ms
# LinearRegression()

# %%
# %%time
LR_train_preds = LR_mdl.predict(train_features)
# Out:
# CPU times: user 45.7 ms, sys: 46.3 ms, total: 92 ms
# Wall time: 19.5 ms

# %%
LR_train_rmse = RMSE(train_target, LR_train_preds)

# %%
f"RMSE для модели линейной регрессии на обучающей выборке: {round(LR_train_rmse, 2)}"
# Out:
# 'RMSE для модели линейной регрессии на обучающей выборке: 30.64'

# %%
LR_preds_and_true_target_comparison = pd.DataFrame({
    'linear_reg_predictions' : LR_train_preds,
    'true_target' : train_target
})

# %%
LR_preds_and_true_target_comparison['2018-08'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### SGDRegressor

# %%
SGD_LR_mdl = SGDRegressor(random_state=12345, shuffle=False)

# %%
# зададим сетку параметров для обучения
SGD_params_grid = {'alpha' : [0.0001, 0.001],
                   'max_iter': [1e3, 1e4, 1e5],
                   'eta0': [0.1, 0.01, 0.001]}

# %%
# %%time
grid_SGD = GridSearchCV(SGD_LR_mdl, SGD_params_grid, scoring=scorer, cv=3)
# Out:
# CPU times: user 69 µs, sys: 0 ns, total: 69 µs
# Wall time: 74.6 µs

# %%
grid_SGD.fit(train_features, train_target)
# Out:
# GridSearchCV(cv=3, estimator=SGDRegressor(random_state=12345, shuffle=False),
#              param_grid={'alpha': [0.0001, 0.001], 'eta0': [0.1, 0.01, 0.001],
#                          'max_iter': [1000.0, 10000.0, 100000.0]},
#              scoring=make_scorer(RMSE, greater_is_better=False))

# %%
print(grid_SGD.best_score_)
print(grid_SGD.best_params_)
# Out:
# -30.652426930412762
# {'alpha': 0.0001, 'eta0': 0.001, 'max_iter': 1000.0}

# %%
SGD_LR_mdl = SGDRegressor(random_state=12345, alpha=0.0001, max_iter=1000.0, eta0=0.001)

# %%
# %%time
SGD_LR_mdl.fit(train_features, train_target)
# Out:
# CPU times: user 16.8 ms, sys: 171 µs, total: 16.9 ms
# Wall time: 15.5 ms
# SGDRegressor(eta0=0.001, max_iter=1000.0, random_state=12345)

# %%
# %%time
SGD_train_preds = SGD_LR_mdl.predict(train_features)
# Out:
# CPU times: user 5.65 ms, sys: 21 ms, total: 26.7 ms
# Wall time: 8.68 ms

# %%
print('RMSE на обучающей выборке для SGDRegressor: ', RMSE(train_target, SGD_train_preds).round(2))
# Out:
# RMSE на обучающей выборке для SGDRegressor:  30.64

# %%
SGD_preds_and_true_target_comparison = pd.DataFrame({
    'SGD_reg_predictions' : SGD_train_preds,
    'true_target' : train_target
})

# %%
SGD_preds_and_true_target_comparison['2018-08'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### XGBRegressor

# %%
XGBRegressor_mdl = XGBRegressor(n_jobs=-1, verbosity=0)

# %%
XGB_params_grid = {'max_depth': [2, 4, 6],
                   'n_estimators': [50, 100, 200],
                   'learning_rate': [0.1, 0.3, 0.5]}

# %%
grid_XGB = GridSearchCV(XGBRegressor_mdl, XGB_params_grid, scoring=scorer, cv=3)

# %%
# %%time
grid_XGB.fit(train_features, train_target)
# Out:
# CPU times: user 1h 26min 29s, sys: 44.4 s, total: 1h 27min 13s
# Wall time: 1h 28min 32s
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=-1,
#                                     num_parallel_tree=None, predictor=None,
# ...

# %%
print(grid_XGB.best_score_)
print(grid_XGB.best_params_)
# Out:
# -21.803426067022002
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 200}

# %%
XGBRegressor_mdl = XGBRegressor(n_jobs=-1, verbosity=0, random_state=12345, max_depth = 4, 
                                n_estimators = 200, learning_rate = 0.1)

# %%
# %%time
XGBRegressor_mdl.fit(train_features, train_target)
# Out:
# CPU times: user 1min 47s, sys: 862 ms, total: 1min 48s
# Wall time: 1min 49s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#              max_depth=4, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=200, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=12345,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
# %%time
XGB_train_preds = XGBRegressor_mdl.predict(train_features)
# Out:
# CPU times: user 53.8 ms, sys: 8.65 ms, total: 62.4 ms
# Wall time: 17.2 ms

# %%
print('RMSE на обучающей выборке для XGBRegressor: ', RMSE(train_target, XGB_train_preds).round(2))
# Out:
# RMSE на обучающей выборке для XGBRegressor:  12.48

# %%
XGB_preds_and_true_target_comparison = pd.DataFrame({
    'XGB_predictions' : XGB_train_preds,
    'true_target' : train_target
})

# %%
XGB_preds_and_true_target_comparison['2018-08'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### CatBoostRegressor

# %%
CatBoost_mdl = CatBoostRegressor(random_state=12345)
CB_params_grid = {'max_depth': [2, 4, 6],
                  'learning_rate': [0.03, 0.1],
                  'l2_leaf_reg': [1, 3, 5, 7, 9],
                  'iterations': [50, 100, 200]}

# %%
# %%time
CB_grid = CatBoost_mdl.grid_search(CB_params_grid, 
                                   X=train_features, 
                                   y=train_target, 
                                   plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 85.4188663	test: 84.6401054	best: 84.6401054 (0)	total: 47.1ms	remaining: 2.31s
# 1:	learn: 83.3089867	test: 82.4986667	best: 82.4986667 (1)	total: 47.9ms	remaining: 1.15s
# 2:	learn: 81.2283854	test: 80.3953373	best: 80.3953373 (2)	total: 48.4ms	remaining: 759ms
# 3:	learn: 79.2648005	test: 78.4158626	best: 78.4158626 (3)	total: 48.8ms	remaining: 562ms
# 4:	learn: 77.4303005	test: 76.5731270	best: 76.5731270 (4)	total: 49.2ms	remaining: 443ms
# 5:	learn: 75.5625598	test: 74.6869108	best: 74.6869108 (5)	total: 49.7ms	remaining: 364ms
# 6:	learn: 73.8014235	test: 72.9225265	best: 72.9225265 (6)	total: 50.1ms	remaining: 308ms
# 7:	learn: 72.0345466	test: 71.1157113	best: 71.1157113 (7)	total: 50.6ms	remaining: 266ms
# 8:	learn: 70.3464968	test: 69.4247561	best: 69.4247561 (8)	total: 51.1ms	remaining: 233ms
# 9:	learn: 68.7319845	test: 67.7937905	best: 67.7937905 (9)	total: 51.5ms	remaining: 206ms
# ...

# %%
CatBoost_mdl.get_params()
# Out:
# {'loss_function': 'RMSE',
#  'random_state': 12345,
#  'depth': 6,
#  'l2_leaf_reg': 1,
#  'iterations': 200,
#  'learning_rate': 0.1}

# %%
CatBoost_mdl.get_best_score()
# Out:
# {'learn': {'RMSE': 12.787788709040784}}

# %%
# %%time
CatBoost_mdl.fit(train_features, train_target, verbose=10)
# Out:
# 0:	learn: 36.7721256	total: 2.81ms	remaining: 559ms
# 10:	learn: 25.7912092	total: 30.1ms	remaining: 516ms
# 20:	learn: 21.8471664	total: 57.1ms	remaining: 487ms
# 30:	learn: 20.0702717	total: 84.9ms	remaining: 463ms
# 40:	learn: 18.8258743	total: 105ms	remaining: 407ms
# 50:	learn: 18.1287178	total: 120ms	remaining: 349ms
# 60:	learn: 17.4336817	total: 136ms	remaining: 309ms
# 70:	learn: 16.8804563	total: 152ms	remaining: 276ms
# 80:	learn: 16.4117445	total: 167ms	remaining: 246ms
# 90:	learn: 15.9135690	total: 184ms	remaining: 220ms
# 100:	learn: 15.4570996	total: 200ms	remaining: 196ms
# 110:	learn: 15.0435632	total: 216ms	remaining: 173ms
# 120:	learn: 14.7129647	total: 232ms	remaining: 151ms
# 130:	learn: 14.4639138	total: 247ms	remaining: 130ms
# 140:	learn: 14.1631396	total: 263ms	remaining: 110ms
# 150:	learn: 13.8625814	total: 279ms	remaining: 90.6ms
# 160:	learn: 13.5932696	total: 295ms	remaining: 71.4ms
# 170:	learn: 13.3465925	total: 311ms	remaining: 52.7ms
# ...

# %%
# %%time
CatBoost_train_preds = CatBoost_mdl.predict(train_features)
# Out:
# CPU times: user 3.16 ms, sys: 0 ns, total: 3.16 ms
# Wall time: 2.04 ms

# %%
print('RMSE на обучающей выборке для CatBoostRegressor: ', RMSE(train_target, CatBoost_train_preds).round(2))
# Out:
# RMSE на обучающей выборке для CatBoostRegressor:  12.79

# %%
CatBoost_preds_and_true_target_comparison = pd.DataFrame({
    'CatBoost_predictions' : CatBoost_train_preds,
    'true_target' : train_target
})

# %%
CatBoost_preds_and_true_target_comparison['2018-07-13':'2018-07-15'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### LGBMRegressor

# %%
LGBM_mdl = LGBMRegressor(random_state=12345)

# %%
LGBM_params_grid = {'max_depth': [2, 4, 6],
                    'learning_rate': [0.03, 0.1],
                    'n_estimators': [50, 100, 200, 500, 1000]}

# %%
LGBM_grid = GridSearchCV(LGBM_mdl, LGBM_params_grid, scoring=scorer, cv=3)

# %%
# %%time
LGBM_grid.fit(train_features, train_target, verbose=True)
# Out:
# CPU times: user 1h 47min 28s, sys: 43.7 s, total: 1h 48min 12s
# Wall time: 1h 49min 17s
# GridSearchCV(cv=3, estimator=LGBMRegressor(random_state=12345),
#              param_grid={'learning_rate': [0.03, 0.1], 'max_depth': [2, 4, 6],
#                          'n_estimators': [50, 100, 200, 500, 1000]},
#              scoring=make_scorer(RMSE, greater_is_better=False))

# %%
print(LGBM_grid.best_score_)
print(LGBM_grid.best_params_)
# Out:
# -21.80743897130898
# {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}

# %%
# %%time
LGBM_mdl = LGBMRegressor(max_depth=6, n_estimators=500, learning_rate=0.3, random_state=12345)
LGBM_mdl.fit(train_features, train_target)
# Out:
# CPU times: user 2min 17s, sys: 884 ms, total: 2min 18s
# Wall time: 2min 20s
# LGBMRegressor(learning_rate=0.3, max_depth=6, n_estimators=500,
#               random_state=12345)

# %%
# %%time
LGBM_train_preds = LGBM_mdl.predict(train_features)
# Out:
# CPU times: user 164 ms, sys: 4.32 ms, total: 168 ms
# Wall time: 189 ms

# %%
print('RMSE на обучающей выборке для LGBMRegressor: ', RMSE(train_target, LGBM_train_preds).round(2))
# Out:
# RMSE на обучающей выборке для LGBMRegressor:  3.38

# %%
LGBM_preds_and_true_target_comparison = pd.DataFrame({
    'LGBM_predictions' : LGBM_train_preds,
    'true_target' : train_target
})

# %%
LGBM_preds_and_true_target_comparison['2018-07-13':'2018-07-15'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### Выводы

# %% [markdown]
# На валидационной выборке качество оценки модели падает на всех моделях. Но как мы ранее видели по графику, характер временного ряда таков, что данные немного различаются, т.к. ближе к хвосту ряда изменения среднего значения происходят бвстрее.
# Модели градиентного бустинга показали себя лучше, чем модель линейной регрессии и стохастического градиентного спуска. RMSE на моделях градиентного бустинга находится в очень близких значениях.

# %% [markdown]
# ## Тестирование

# %% [markdown]
# ### LinearRegression

# %%
# %%time
LR_test_preds = LR_mdl.predict(test_features)
# Out:
# CPU times: user 266 µs, sys: 2 µs, total: 268 µs
# Wall time: 246 µs

# %%
print('RMSE для модели линейной регрессии на тестовой выборке: ', RMSE(test_target, LR_test_preds).round(2))
# Out:
# RMSE для модели линейной регрессии на тестовой выборке:  51.2

# %%
LR_test_preds_and_true_test_target_comparison = pd.DataFrame({
    'LR_predictions' : LR_test_preds,
    'true_target' : test_target
})

# %%
LR_test_preds_and_true_test_target_comparison['2018-08-30':'2018-08-31'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### SGDRegressor

# %%
# %%time
SGD_test_preds = SGD_LR_mdl.predict(test_features)
# Out:
# CPU times: user 238 µs, sys: 2 µs, total: 240 µs
# Wall time: 248 µs

# %%
print('RMSE на тестовой выборке для SGDRegressor: ', RMSE(test_target, SGD_test_preds).round(2))
# Out:
# RMSE на тестовой выборке для SGDRegressor:  51.2

# %%
SGD_test_preds_and_true_test_target_comparison = pd.DataFrame({
    'SGD_predictions' : SGD_test_preds,
    'true_target' : test_target
})

# %%
SGD_test_preds_and_true_test_target_comparison['2018-08-30':'2018-08-31'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### XGBRegressor

# %%
# %%time
XGB_test_preds = XGBRegressor_mdl.predict(test_features)
# Out:
# CPU times: user 47.1 ms, sys: 0 ns, total: 47.1 ms
# Wall time: 44.7 ms

# %%
print('RMSE на тестовой выборке для XGBRegressor: ', RMSE(test_target, XGB_test_preds).round(2))
# Out:
# RMSE на тестовой выборке для XGBRegressor:  41.59

# %%
XGB_test_preds_and_true_test_target_comparison = pd.DataFrame({
    'XGB_predictions' : XGB_test_preds,
    'true_target' : test_target
})

# %%
XGB_test_preds_and_true_test_target_comparison['2018-08-30':'2018-08-31'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### CatBoostRegressor

# %%
# %%time
CatBoost_test_preds = CatBoost_mdl.predict(test_features)
# Out:
# CPU times: user 0 ns, sys: 2.49 ms, total: 2.49 ms
# Wall time: 1.31 ms

# %%
print('RMSE на тестовой выборке CatBoostRegressor: ', RMSE(test_target, CatBoost_test_preds).round(2))
# Out:
# RMSE на тестовой выборке CatBoostRegressor:  39.7

# %%
CatBoost_test_preds_and_true_test_target_comparison = pd.DataFrame({
    'CatBoost_predictions' : CatBoost_test_preds,
    'true_target' : test_target
})

# %%
CatBoost_test_preds_and_true_test_target_comparison['2018-08-30':'2018-08-31'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### LGBMRegresor

# %%
# %%time
LGBM_test_preds = LGBM_mdl.predict(test_features)
# Out:
# CPU times: user 67.1 ms, sys: 95 µs, total: 67.2 ms
# Wall time: 58.6 ms

# %%
print('RMSE на тестовой выборке для LGBMRegressor: ', RMSE(test_target, LGBM_test_preds).round(2))
# Out:
# RMSE на тестовой выборке для LGBMRegressor:  41.27

# %%
LGBM_test_preds_and_true_test_target_comparison = pd.DataFrame({
    'LGBM_predictions' : LGBM_test_preds,
    'true_target' : test_target
})

# %%
LGBM_test_preds_and_true_test_target_comparison['2018-08-30':'2018-08-31'].plot(figsize=(16,4), title='True and prediction values comparison')
# Out:
# <AxesSubplot:title={'center':'True and prediction values comparison'}, xlabel='datetime'>

# %% [markdown]
# ### Выводы

# %%
analysis_results = {'Модель':['LinearRegression', 'SGDRegressor', 'XGBRegressor', 'CatBoostRegressor', 'LGBMRegressor'], 
                        'Скорость обучения':['2.64 ms', '15.5 ms', '1 min 49 s', '1.43 s', '2 min 20 s'],
                        'Скорость предсказания':['246 µs', '248 µs', '47.1 ms', '2.49 ms', '67.2 ms'],
                        'RMSE': [51.2, 51.2, 41.59, 37.7, 41.27]}

# %%
analysis_results = pd.DataFrame(analysis_results)

# %%
analysis_results
# Out:
#               Модель Скорость обучения Скорость предсказания   RMSE
# 0   LinearRegression           2.64 ms                246 µs  51.20
# 1       SGDRegressor           15.5 ms                248 µs  51.20
# 2       XGBRegressor        1 min 49 s               47.1 ms  41.59
# 3  CatBoostRegressor            1.43 s               2.49 ms  37.70
# 4      LGBMRegressor        2 min 20 s               67.2 ms  41.27

# %% [markdown]
# Почти все модели показали результат RMSE ниже тебуемого значения в 48 на тестовой выборке.
#
# Модели градиентного бустинга XGBRegressor, CatBoostRegressor, LGBMRegressor показали значительно лучшие результаты на тестовой выборке, чем модель линейной регрессии и модель градиентного стохастического спуска.
#
# Наиболее оптимальной в соотношении скорость обучения и предсказания - качество работы модели показала себя модель градиентного бустинга CatBoostRegressor, но наилучшее значение RMSE у модели градиентного бустинга XGBRegressor.
